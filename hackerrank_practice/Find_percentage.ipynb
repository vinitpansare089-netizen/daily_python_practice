# %%
students = {
    "Krishna": [67, 68, 69],
    "Arjun": [70, 98, 63],
    "Malika": [52, 56, 60]
}



query_name = "Krishna" 
# query_name = input()

marks = students[query_name]
avg = sum(marks) / len(marks)
print(f"{avg:.2f}")

# print(students.keys())
# print(students.values())
# Out:
# 68.00
# dict_keys(['Krishna', 'Arjun', 'Malika'])
# dict_values([[67, 68, 69], [70, 98, 63], [52, 56, 60]])

# %%
data = {
    "A": [10, 20, 30],
    "B": [40, 50, 60]
}

print(data["B"][2])
# Out:
# 60

# %%
data = {
    "x": [5, 15, 25],
    "y": [35, 45, 55]
}

print(data["x"][0])
# Out:
# 5

# %%
data = {
    "student": {
        "marks": [10, 20, 30]
    }
}

print(data["student"]["marks"][2])
# Out:
# 30
