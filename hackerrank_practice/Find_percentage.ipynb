# %%
students = {
    "Krishna": [67, 68, 69],
    "Arjun": [70, 98, 63],
    "Malika": [52, 56, 60]
}

query_name = "Krishna"

marks = students[query_name]
avg = sum(marks) / len(marks)
print(f"{avg:.2f}")
# Out:
# 68.00
