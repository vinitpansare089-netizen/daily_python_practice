# %%
from collections import defaultdict

def group_numbers(nums):
    d = defaultdict(list)

    for num in nums:
        key = 'div_by_3' if num % 3 == 0 else 'not_div_by_3'
        d[key].append(num)

    return dict(d)
    
nums = [12, 25, 30, 7, 18]
print(group_numbers(nums))
# Out:
# {'div_by_3': [12, 30, 18], 'not_div_by_3': [25, 7]}

# %%
from collections import defaultdict

def group_numbers(nums, condition):
    d = defaultdict(list)

    for num in nums:
        key = condition(num)
        d[key].append(num)

    return dict(d)

def check(num):
    return 'divisible_by_3' if num % 3 == 0 else 'not_divisible_by_3'

def size_check(num):
    if num <= 10:
        return 'small'
    elif 11 <= num <= 20:
        return 'medium'
    else:
        return 'Large'

# nums = [12, 25, 30 ,7, 18]
print(group_numbers(nums, size_check))
# Out:
# {'medium': [12, 18], 'Large': [25, 30], 'small': [7]}
