# %%
n = int(input())
arr = list(map(int, input().split()))

print(arr)
# Out:
# [12]

# %%
### Using lembda functions

arr = [2,4,6]
arr2 = [1,3,5,7]
result = map(lambda x,y: x * y, arr, arr2)
print(list(result))
# Out:
# [2, 12, 30]
