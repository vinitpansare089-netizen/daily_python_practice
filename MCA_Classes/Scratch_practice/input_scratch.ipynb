# %%
n = int(input())
arr = list(map(int, input().split()))

print(arr)
# Out:
# [12, 12]

# %%
### Using lembda functions

arr = [2,4,6]
arr2 = [1,3,5,7]
result = map(lambda x,y: x * y, arr, arr2)
print(list(result))
# Out:
# [2, 12, 30]

# %%
"""
A company gives me n numbers and i have to make it to return a maximum number
"""

N = int(input())
arr = list(map(int, input().split()))

#print(arr)
maximum = arr[0]

for num in arr:
    if num > maximum:
        maximum = num

print(maximum)
# Out:
# 87

# %%
"""
Sorting algorithms
"""

N = int(input())
arr = list(map(int, input().split()))

for i in range(N):
    min_index = i

    for j in range(i + 1, N):
        if arr[j] < arr[min_index]:
            min_index = j

    arr[i], arr[min_index] = arr[min_index], arr[i]

print(*arr)
# Out:
# 1 43 65 78 88

# %%
"""
taking multiple arrays 
"""
T = int(input())

for _ in range(T):

    N = int(input())
    arr = list(map(int, input().split()))

    for i in range(N):
        min_index = i

    for j in range(i + 1, N):
        if arr[j] < arr[min_index]:
            min_index = j

    arr[i], arr[min_index] = arr[min_index], arr[i]

    print(*arr)
# Out:
# 23 45 1
# 11 56 34 98 2

# %%
"""
Input handling with multiple inputs 
"""

N, k = map(int, input().split())
arr = list(map(int, input().split()))


if k in arr:
    print(True)
else:
    print(False)
# Out:
# False

# %%
"""
Taking the string as input
"""
s = input()

count = 0
vowels = ['a','e','i','o','u']

for char in s.lower():
    if char in vowels:
        count += 1

print(count)
# Out:
# 3
