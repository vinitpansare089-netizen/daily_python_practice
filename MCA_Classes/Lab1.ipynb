# %%
"""
Lab 1 of python in MCA clases
"""

print("vinti")
# Out:
# vinti

# %%
def add(a: float,b: float) -> int:
   """
        Addition function:
        - takes two inputs
        - store addition in total
        - return the total
        - passed value
        - print result.
   """
   return a + b
    
result = add(1,2) ## 3

print(add(3,4)) ## 7
print(result)
# Out:
# 7
# 3

# %%
print("vinit is a good boy\ni am very proud of me,\ni will\tbecome a beast\tin python\n BackSlash : \\\ni\'m goood")

print("this is \rhigh chance")
# Out:
# vinit is a good boy
# i am very proud of me,
# i will	become a beast	in python
#  BackSlash : \
# i'm goood
# high chance
