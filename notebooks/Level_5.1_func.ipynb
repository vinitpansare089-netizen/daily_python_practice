# %%
def greet(name):
    return f'Hello {name}'

print(greet("Vinit")) 
print(greet("Yashi"))
# Out:
# Hello Vinit
# Hello Yashi

# %%
def greet(name):
    return f'Hello {name}'

result = greet("Vinit")
print(result)
# Out:
# Hello Vinit

# %%
#params vs arguments

def add(a, b):#///params
    return a + b

print(add(2,3))#///argumemts
# Out:
# 5

# %%
def calculate_avg(marks):
    return sum(marks)/len(marks)

# print(calculate_avg([45,45,45]))
avg = calculate_avg([3, 3, 3])
print(avg)
# Out:
# 3.0

# %%
def Greet(name = "Vinit"):
    return f'Hello {name}'

print(Greet())
print(Greet("Yashi"))
print(Greet)
# Out:
# Hello Vinit
# Hello Yashi
# <function Greet at 0x0000024551B9B9C0>
