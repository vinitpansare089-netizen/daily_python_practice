# %%
def greet(name):
    return f'Hello {name}'

print(greet("Vinit")) 
print(greet("Yashi"))
# Out:
# Hello Vinit
# Hello Yashi

# %%
def greet(name):
    return f'Hello {name}'

result = greet("Vinit")
print(result)
# Out:
# Hello Vinit

# %%
#params vs arguments

def add(a, b):#///params
    return a + b

print(add(2,3))#///args
# Out:
# 5

# %%
def calculate_avg(marks):
    return sum(marks)/len(marks)

# print(calculate_avg([45,45,45]))
avg = calculate_avg([3, 3, 3])
print(avg)
# Out:
# 3.0

# %%
def Greet(name = "Vinit"):
    return f'Hello {name}'

print(Greet())
print(Greet("Yashi"))
print(Greet)
# Out:
# Hello Vinit
# Hello Yashi
# <function Greet at 0x0000024551B9B9C0>

# %%
def square(a):
    return a*a

print(square(4))

# Create function:
# takes list
# returns max value

def max_list(lst):
    return max(lst)

l = max_list([2,6,8,4])

print(l)
# Out:
# 16
# 8

# %%
def greet(default = "User"):
    return f'Hello {default}'

print(greet())
# Out:
# Hello User

# %%
# Create function:

#  takes marks list
# returns:

# average
# highest mark

# def avg_hig_mark(marks):
#     return sum(marks)/len(marks) ,max(marks), min(marks)

def avg_hig_mark(marks):
    avg = sum(marks)/len(marks)
    high = max(marks)
    low = min(marks)

    return avg, high, low

avg, high, low = avg_hig_mark([12,23,34,45])
print(result)
# Out:
# (28.5, 45, 12)
