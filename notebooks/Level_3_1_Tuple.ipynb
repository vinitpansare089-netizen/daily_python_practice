# %% [markdown]
# <a href="https://colab.research.google.com/github/vinitpansare089-netizen/daily_python_practice/blob/main/Level_3_1_Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
coordinates = (10.2, 30.4, 50.4)
print(f"X: {coordinates[0]}, Y: {coordinates[1]}, Z: {coordinates[2]}")
# Out:
# X: 10.2, Y: 30.4, Z: 50.4

# %%
#  Input must be a dictionary
#  Dictionary must not be empty
#  Keys must be strings
#  Values must be numbers\
#  Return (best_key, best_value)

#------------Version 1

# from numbers import Number

# def best_model(scores: dict) -> tuple:
#   if not isinstance(scores, dict):

#     raise TypeError("Input must be distionary")

#   if len(scores) == 0:

#     raise ValueError("Distionary should not be empty")


# def best_key(keys: str) -> tuple:

#   if not isinstance(keys, str):
#     raise ValueError("Keys must be strings")

# def best_value(value: float) -> float:

#   if not isinstance(value, Number):

#     raise ValueError("Value must be in Number")

# return(best_key, best_value)


#-------------Version 2

from numbers import Number

def best_model(scores: dict) -> tuple:
  if not isinstance(scores, dict):
    raise TypeError("Input must be distionary")

  if len(scores) == 0:
    raise ValueError("Distionary should not be empty")

  for k,v in scores.items():
    if not isinstance(k, str):
      raise ValueError("keys must be string")

    if not isinstance(v, Number):
      raise ValueError("Values must be Numbers")

  best_key = None
  best_value = None
  


  for k, v in scores.items():
    if best_value is None or v > best_value:
      best_key = k
      best_value = v

  return best_key, best_value

scores = {
    "model_1": 72.1,
    "model_2": 93.2,
    "model_3": 91.3
}

print(best_model(scores))
# Out:
# ('model_2', 93.2)
