# %%
class Student:
    def __init__(self, name):
        #print("vinit")
        self.name = name
        
s1 = Student("Vinit")
s2 = Student("Mahi")

print(s1.name)
print(s2.name)
# Out:
# Vinit
# Mahi
