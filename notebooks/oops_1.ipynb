# %%
class Student:
    def __init__(self, name):
        #print("vinit")
        self.name = name
        
s1 = Student("Vinit")
s2 = Student("Mahi")

print(s1.name)
print(s2.name)
# Out:
# Vinit
# Mahi

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def Say_hello(self):
        print("Hello, i am ",self.name)

s1 = Student("Vinit")
s1.Say_hello()
# Out:
# Hello, i am  Vinit
