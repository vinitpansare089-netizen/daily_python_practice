# %%
def multiplier(x):
    x = 10

    def multiply(x):
        return x * x

    return multiply

result = multiplier(5)

print(result(10))##100
# Out:
# 100

# %%
def multiplier(n):
    """     
        multiplier takes .....

    """
    def multiply(x):
        return x * n
    
    
    return multiply

func = multiplier(10)

print(func(20))##200
# Out:
# 200

# %%
def power(n):

    def calc(x):
        return x ** n

    return calc
square = power(2)
cube = power(3)

print(square(2))
print(cube(5))
# Out:
# 4
# 125

# %%
def power(n):
    
    def calc(x):
        return x ** n
    
    return calc

square = power(2)
cube = power(3)

print(square(2))
print(cube(3))
# Out:
# 4
# 27

# %%
def multiplier(n):

    def multiply(x):
        return x * n

    return multiply

func = multiplier(4)

print(func(4))###16
# Out:
# 16
