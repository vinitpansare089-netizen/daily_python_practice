# %%
def multiplier(x):
    x = 10

    def multiply(x):
        return x * x

    return multiplier

result = multiplier()

print(result(10))

# %%
def multiplier(n):

    def multiply(x):
        return x * n
    
    return multiply

func = multiplier()

print(func(20))
