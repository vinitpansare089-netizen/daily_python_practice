# %%
def multiplier(x):
    x = 10

    def multiply(x):
        return x * x

    return multiply

result = multiplier(5)

print(result(10))
# Out:
# 100

# %%
def multiplier(n):

    def multiply(x):
        return x * n
    
    return multiply

func = multiplier(10)

print(func(20))
# Out:
# 200
