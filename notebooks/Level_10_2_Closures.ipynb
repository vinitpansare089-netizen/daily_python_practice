# %%
def multiplier(x):
    x = 10

    def multiply(x):
        return x * x

    return multiply

result = multiplier(5)

print(result(10))
# Out:
# 100

# %%
def multiplier(n):

    def multiply(x):
        return x * n
    
    return multiply

func = multiplier(10)

print(func(20))
# Out:
# 200

# %%
def power(n):

    def calc(x):
        return x ** n
    
    return calc

square = power(2)
cube = power(3)

print(square(2))
print(cube(5))
# Out:
# 4
# 125

# %%
def power(n):
    
    def calc(x):
# Out:
#   Cell In[1], line 3
#     def calc(x):
#                 ^
# SyntaxError: incomplete input

# %%
re
