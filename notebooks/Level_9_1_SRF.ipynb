# %%
def load_csv(filepath):
    pass

def preprosessing(df):
    pass

def Encode(df):
    pass

def cleaned_file(df):
    pass

# %%
def load_csv():
    pass

def missing_values(df):
    pass

def clean_data(df):
    pass
