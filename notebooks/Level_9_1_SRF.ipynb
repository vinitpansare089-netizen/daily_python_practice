# %%
def load_csv():
    pass

def missing_values(df):
    pass

def clean_data(df):
    pass

def generate_report(df):
    pass

def save_file(df):
    pass

# %%
data = load(filepath)
cleaned = clean(data)
encoded = encode(cleaned)
save(encoded)
