# %%
def load_csv():
    pass

def missing_values(df):
    pass

def clean_data(df):
    pass

def generate_report(df):
    pass

def save_file(df):
    pass

# %%
def load(filepath):
    pass
def clean(df):
    pass
def encode(df):
    pass
def save(df):
    pass
