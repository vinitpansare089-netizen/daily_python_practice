# %%
def load_csv():
    pass

def missing_values(df):
    pass

def clean_data(df):
    pass

def generate_report(df):
    pass

def save_file(df):
    pass

# %%
# upload image
# preprocess image
# run model
# return result

uploaded = upload_img(image.png)
process = preprocess_img(uploaded)
model = model_run(process)
result model
