# %%
def load_csv():
    pass

def missing_values(df):
    pass

def clean_data(df):
    pass

def generate_report(df):
    pass

def save_file(df):
    pass

# %%
# Need to:

# load dataset
# split X, y
# train model
# predict

data = load_data(filepath)

X, y = split(data)

model = train(X, y)

prediction = predict(model, X)
