# %%
def my_info(**kwargs):
    return kwargs

info = my_info(name="Vinit", age=23, add="Indore")

print(info)
# Out:
# {'name': 'Vinit', 'age': 23, 'add': 'Indore'}

# %%
def st_info(**kwargs):
    for k ,val in kwargs.items():
        print(k)
    
st_info(st1="Hashit", st2="Vinit", st3="Abhi", st4="Ayush")
# Out:
# st1
# st2
# st3
# st4
