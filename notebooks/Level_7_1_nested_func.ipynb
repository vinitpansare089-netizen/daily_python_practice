# %%
def outer(x):
    def inner(y):
        return y * 2
    return inner(x)

print(outer(4))#//8
# Out:
# 8

# %%
def num1(x):
    def num2(y):
        return y ** 2
    return num2(x)


print(num1(6))

# %%
def apply_func(func, value):
    return func(value)

def square(x):
    return x * x

print(apply_func(square, 5))
# Out:
# 25

# %%
def apply_function(func, x):
    return func(x)

def cube(x):
    return x * x * x

print(apply_function(cube, 5))
# Out:
# 125

# %%
# Q2:

# Create 2 functions:

# double(x)
# square(x)

def apply_func(func, x):
    return func(x)

def double(x):
    return x + x

def square(x):
    return x * x

print(apply_func(double, 5))
print(apply_func(square, 5))
# Out:
# 10
# 25

# %%
multiply =  lambda x ,y: x * y

multiply(5, 3)
# Out:
# 15

# %%
def apply_func(func, value):
    return func(value)

apply_func(lambda x: x + 10, 5)
# Out:
# 15

# %%
nums = [1,2,3,4]

result = []

for i in nums:
    result.append(i * i)

print(result)
# Out:
# [1, 4, 9, 16]

# %%
ev_odd = lambda x: "Even" if x % 2 == 0 else "Odd"

ev_odd(1)
# ev_odd(4)
# Out:
# 'Odd'

# %%
nums = [1,2,3,4]
result = map(lambda x: x * x, nums)

print(list(result))
# Out:
# [1, 4, 9, 16]

# %%
lst = ["vinit", "harshit"]
result = map(lambda x: x.upper(), lst)

print(list(result))
# Out:
# ['VINIT', 'HARSHIT']

# %%
nums = [1,2,3,4]
result = map(lambda x: x + x, nums)

list(result)
# list(result) # -> on 2nd time []
# Out:
# [2, 4, 6, 8]
