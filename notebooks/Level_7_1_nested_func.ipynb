# %%
def outer(x):
    def inner(y):
        return y * 2
    return inner(x)

print(outer(4))#//8
# Out:
# 8

# %%
def num1(x):
    def num2(y):
        return y ** 2
    return num2(x)

print(num1(6))
