# %%
# Write:

# def calculate_avg(marks):

# Add:

# docstring
# return average

def calculate_avg(marks: list[int]) -> float:

    """ 
            takes marks as an list haing all int element
    """

    if not all(isinstance(x, int) for x in marks):
        raise TypeError('Only int allowed')

    return sum(marks) / len(marks)

# print(calculate_avg([1,2.9,3.3,4.5]))
print(calculate_avg([1,2,3,4,5]))


print(calculate_avg.__doc__)
# Out:
# 3.0
#
#             takes marks as an list haing all int element

# %%
# Write:

# def calculate_avg(marks):

# Add:

# docstring
# return average

def calculate_avg(marks: list[int]) -> float:
    
    return sum(marks) / len(marks)

result = calculate_avg[1,2,3,4,5,6,7,8]

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 14
#      10 def calculate_avg(marks: list[int]) -> float:
#      12     return sum(marks) / len(marks)
# ---> 14 result = calculate_avg[1,2,3,4,5,6,7,8]
#      16 print(result)
#
# TypeError: 'function' object is not subscriptable

# %%
# 🧪 Task 2

# Add type hints:

# def greet(name):

# Should return:

# Hello Vinit

# with type hints.

def greet(name: str) -> str:
    return f'Hello {name}'

print(greet("vinit"))
# Out:
# Hello vinit

# %%
def greet(name: str) -> str:
    return f'Hello {name}'

print(greet("vinit"))
# Out:
# Hello vinit

# %%
# Add a docstring to:

# def greet(name: str) -> str:

# Explain:

# purpose
# parameter
# return

def greet(name: str) -> str:
    """ this function take name as input in string form
    
        and gives output as string also

        and return name with default "hello"    
    """
    return f'Hello {name}'
