# %%
# Write:

# def calculate_avg(marks):

# Add:

# docstring
# return average

def calculate_avg(marks: list[int]) -> int:

    if not all(isinstance(x, int) for x in marks):
        raise TypeError('Only int allowed')
    
    """ 
            takes marks as an list haing all int element
    """
    
    return int(sum(marks) / len(marks))

# print(calculate_avg([1,2.9,3.3,4.5]))
print(calculate_avg([1,2,3,4,5]))


# help(calculate_avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 21
#      15     """
#      16             takes marks as an list haing all int element
#      17     """
#      19     return int(sum(marks) / len(marks))
# ---> 21 print(calculate_avg([1,2.9,3.3,4.5]))
#      22 print(calculate_avg([1,2,3,4,5]))
#      25 # help(calculate_avg)
#
# Cell In[8], line 13, in calculate_avg(marks)
#      10 def calculate_avg(marks: list[int]) -> int:
#      12     if not all(isinstance(x, int) for x in marks):
# ---> 13         raise TypeError('Only int allowed')
#      15     """
#      16             takes marks as an list haing all int element
#      17     """
#      19     return int(sum(marks) / len(marks))
#
# TypeError: Only int allowed

# %%
# 🧪 Task 2

# Add type hints:

# def greet(name):

# Should return:

# Hello Vinit

# with type hints.

def greet(name: str) -> str:
    return f'Hello {name}'

print(greet("vinit"))
# Out:
# Hello vinit

# %%
# Add a docstring to:

# def greet(name: str) -> str:

# Explain:

# purpose
# parameter
# return

def greet(name: str) -> str:
    """ this function take name as input in string form
    
        and gives output as string also

        and return name with default "hello"    
    """
    return f'Hello {name}'
