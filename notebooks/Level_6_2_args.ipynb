# %%
def add(*args):
    return sum(args)

print(add(1,2,3,4,5))
# Out:
# 15

# %%
def Max_func(*args):
    return args #// (5,)
    #return max(args) // 5

result = Max_func(max([1,2,3,4,5]))

print(result)
# print(type(result))
# Out:
# (5,)
