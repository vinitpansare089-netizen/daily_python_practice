# %%
def add(*args):
    return sum(args)

print(add(1,2,3,4,5))
# Out:
# 15

# %%
# def Max_func(*args):
#     return args #// (5,)
#     #return max(args) // 5

# result = Max_func(max([1,2,3,4,5]))

# print(result)
# # print(type(result))

def max_func(*args):
    return max(args)

result = max_func(1,2,3,4,5)

print(result)
# Out:
# 5

# %%
# def sum_max(*args):
#     sm = sum(args)
#     mx = max(args)

#     return sm, max

# sm, mx = sum_max([1,2,3,4,5])

# print(sm, mx)

def sum_max(*args):
    mx = max(args)
    sm = sum(args)

    return sm, mx

result = sum_max(1,2,3,4,5)
print(result)

def sum_max(*args):
    return max(args), sum(args)

mx, sm = sum_max(12,3,4,56,7,6)

print(mx ,sm)
# Out:
# 56 88

# %%
def sum_count(*nums):
    return max(nums), sum(nums)

num = sum_count(*[10, 20, 30])

print(num)
# Out:
# (30, 60)
