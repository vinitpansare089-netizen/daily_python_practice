# %%
def add(*args):
    return sum(args)

print(add(1,2,3,4,5))
# Out:
# 15

# %%
# def Max_func(*args):
#     return args #// (5,)
#     #return max(args) // 5

# result = Max_func(max([1,2,3,4,5]))

# print(result)
# # print(type(result))

def max_func(*args):
    return max(args)

result = max_func(1,2,3,4,5)

print(result)
# Out:
# 5

# %%
def sum_max(*args):
    sm = sum(args)
    mx = max(args)

    return sm, mx

sm, mx = sum_max([1,2,3,4,5])

print(sm, mx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3     mx = max(args)
#       5     return sm, mx
# ----> 7 sm, mx = sum_max([1,2,3,4,5])
#       9 print(sm, mx)
#
# Cell In[4], line 2, in sum_max(*args)
#       1 def sum_max(*args):
# ----> 2     sm = sum(args)
#       3     mx = max(args)
#       5     return sm, mx
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
