# %% [markdown]
# <a href="https://colab.research.google.com/github/vinitpansare089-netizen/daily_python_practice/blob/main/Level_1_func.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AREA OF CIRCLE

def area_circle(r: float):
  pi = 3.14
  A = pi * (r * r)
  return A

area_circle(6)

#MAX OF THREE NUMBERS

def max_of_three(x: float, y: float, z: float):
  if x>y and x>z:
    return x, "x"
  elif y>z and y>x :
    return y, "y"
  else:
    return z, "z"

value, name = max_of_three(5.23, 4.54, 8.35)

print(int(value) ,name)

#CONVERT CALCIUS TO FEHRENHEIT

def to_fehrenheit(c: float):
  return int((c * 1.8)) + 32

to_fehrenheit(45)
# Out:
# 8 z
# 113
