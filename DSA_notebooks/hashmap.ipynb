# %%
student = {
    "vinit" : 90,
    "Yashi" : 92
}

print(student["vinit"])
# Out:
# 90

# %%
marks = {}

marks["vinit"] = 95
marks["Rahul"] = 90

print(marks["Rahul"])
# Out:
# 90

# %%
data = {}

data[10] = "Python"
data[20] = "DSA"
data[30] = "AI"

print(data[20])
# Out:
# DSA

# %%
seen = {}

seen[5] = "DSA"
seen[10] = "Python"
seen[15] = "Java"

print(5 in seen)
print(20 in seen)
print(seen[5])
# Out:
# True
# False
# DSA

# %%
# nums = [7,2,11,15]
# target = 9

# seen = {}

def hashmapping(nums, target):
    seen = {}
    for i, num in enumerate(nums):
        needed = target - num   #// 9 - 7 = 2
        print(seen)
        if needed in seen:
            return([seen[needed], i])
            # print(seen)
        else:
            seen[num] = i

# print(hashmapping(nums=[7,2,11,15], target=9))
print(hashmapping(nums=[7,1,10,2], target=9))
# Out:
# {}
# {7: 0}
# {7: 0, 1: 1}
# {7: 0, 1: 1, 10: 2}
# [0, 3]

# %%
seen = {}

for i in range(5):
    seen[i] = i
    # print(seen)

print(seen)
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}

# %%
count = 0

for i in range(3):
    count += 1
    # print(count)

print(count)
# Out:
# 3
