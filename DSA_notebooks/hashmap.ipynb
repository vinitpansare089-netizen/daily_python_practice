# %%
student = {
    "vinit" : 90,
    "Yashi" : 92
}

print(student["vinit"])
# Out:
# 90

# %%
marks = {}

marks["vinit"] = 95
marks["Rahul"] = 90

print(marks["Rahul"])
# Out:
# 90

# %%
data = {}

data[10] = "Python"
data[20] = "DSA"
data[30] = "AI"

print(data[20])
# Out:
# DSA

# %%
seen = {}

seen[5] = "DSA"
seen[10] = "Python"
seen[15] = "Java"

print(5 in seen)
print(20 in seen)
print(seen[5])
# Out:
# True
# False
# DSA

# %%
nums = [7,2,11,15]
target = 9

seen = {}

for i, num in enumerate(nums):
    needed = target - num   #// 9 - 7 = 2
    if needed in seen:
        return [seen[needed], i]
    else:
        seen[num] = 1
# Out:
#   Cell In[2], line 9
#     return [seen[needed], i]
#     ^
# SyntaxError: 'return' outside function
