# %%
from array import array

my_array = array('i', [10, 20, 30])  # only integers allowed
print(my_array)
# Out:
# ('i', [10, 20, 30])

# %%
nums = [7, 1, 5, 3, 6, 4]

# for num in nums:
print(*nums)
print(nums)
# Out:
# 7 1 5 3 6 4
# [7, 1, 5, 3, 6, 4]

# %%
nums = [7, 1, 5, 3, 6, 4]

lst = []

for i in range(len(nums)):
    lst.append(i)
print(lst)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
nums = [7, 1, 5, 3, 6, 4]

for i, num in enumerate(nums):
    
    print(i,num)
# Out:
# 0 7
# 1 1
# 2 5
# 3 3
# 4 6
# 5 4

# %%
nums = [7, 1, 5, 3, 6, 4]

lst = [0]

for i, num in enumerate(nums):
    if num[i] >
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       1 nums = [7, 1, 5, 3, 6, 4]
#       3 lst = [0]
# ----> 5 for i, num in nums:
#       6     print(i, num)
#
# TypeError: cannot unpack non-iterable int object
