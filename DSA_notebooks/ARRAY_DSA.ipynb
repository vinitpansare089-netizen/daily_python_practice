# %%
from array import array

my_array = array('i', [10, 20, 30])  # only integers allowed
print(my_array)
# Out:
# ('i', [10, 20, 30])

# %%
nums = [7, 1, 5, 3, 6, 4]

for num in nums:
    print(num)
# Out:
# 7
# 1
# 5
# 3
# 6
# 4
