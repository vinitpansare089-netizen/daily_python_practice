# %%
##Finding maximum element

arr = [12, 45, 7, 89, 23, 56]

max = arr[0]

for num in arr:
    if max < num:
        max = num
print(max)
# Out:
# 89

# %%
arr = [12,45,7,89,23,56]

if arr[0] > arr[1]:
    largest = arr[0]
    second_largest = arr[1]
else:
    largest = arr[1]
    second_largest = arr[0]

for num in arr(2:):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 arr = [12,45,7,89,23,56]
# ----> 3 largest = arr[45, 12]
#       4 print(largest)
#
# TypeError: list indices must be integers or slices, not tuple
