# %%
s = "anagram"
t = "nagaram"

freq = {}
freq2 = {} 

for char in s:
    if char in freq:
        # print(freq)
        freq[char] += 1
    else:
        print(freq)
        freq[char] = 1


for char in t:
    if char in freq2:
        freq2[char] += 1
    else:
        freq2[char] = 1
# Out:
# {}
# {'a': 1}
# {'a': 2, 'n': 1}
# {'a': 2, 'n': 1, 'g': 1}
# {'a': 3, 'n': 1, 'g': 1, 'r': 1}

# %%
ransomNote = 'aa'
magazine = 'aab'

freq = {}

for char in ransomNote:
    if char in freq:
        freq[char] += 1
    else:
        freq[char] = 1  
    
freq2 = {}
for char in magazine:
    if char in freq2:
        freq2[char] += 1
    else:
        freq2[char] = 1
