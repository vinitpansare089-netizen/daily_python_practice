# %%
s = "anagram"
t = "nagaram"

freq = {}

for char in s:
    if char in freq:
        # print(freq)
        freq[char] += 1
    else:
        print(freq)
        freq[char] = 1
# Out:
# {}
# {'a': 1}
# {'a': 2, 'n': 1}
# {'a': 2, 'n': 1, 'g': 1}
# {'a': 3, 'n': 1, 'g': 1, 'r': 1}
