# %%
"""

####BRUTE FORCE FIRST#######

Two NUmbers both ae strings 
- First convert it to or make it a int from string 
- second add both and  return even or odd.

"""
#Brute force

# N1 = 3

# N2 = 3

# N3 = N1 + N2

# if N3 % 2 == 0:
#     print("even number")
# else:
#    print("odd number")

# def OddEven(Num1, Num2):
#     """
#     After Manually inserting values 
#     built a function ... 
#     - takes input of two numbers Num1 , Num2 
#     - Then Calculate insert into another variable 
#     - Now check if sum is even or odd 
#     - Call the function 
#     - Passed arguments
#     - store in result variable
#     - Final Print got output

#     """
#     Num3 = Num1 * Num2
#     if Num3 % 2 == 0:
#         return 'Even Number'
#     else:
#         return 'Odd Number'

# result = OddEven(1,3)
# # result = OddEven(3,4)
# print(result)

###########Adding two stings ################


n1 = '1'
n2 = '2'
n = int(n1) + int(n2)
print(n)
# Out:
# 3

# %%
def twoString(n1:str,n2:str ) -> int:
    n3 = int(n1) * int(n2)
    if n3 % 2 == 0:
        return 1
    else:
        return 0

result = twoString('12','15')
print(result)
# Out:
# 1

# %%
arr = [11,24,21,66,33,76,11,26,77,78]
num = 76

print(arr)

print(num)

found = False

for i in range(len(arr)):
    if arr[i] == num:
        found = True
        print(num, num // 10)
        arr[i] = num // 10
    else:
        arr[i] += 1

if not found:
    print("No")

print(arr)
# Out:
# [11, 24, 21, 66, 33, 76, 11, 26, 77, 78]
# 76
# 76 7
# [12, 25, 22, 67, 34, 7, 12, 27, 78, 79]
