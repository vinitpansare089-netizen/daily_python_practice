# %%
word1 = "abc"
word2 = "pqr"

string = ""

i = 0
j = 0

while i < len(word1) and j < len(word2):
    string += word1[i]
    string += word2[j]

    i += 1
    j += 1

print(string)
# Out:
# apbqcr
