# %%
s = 'vinit'
    
# print(s[0])
# print(s[-1])
# print(s[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 s = 'vinit'
# ----> 3 for i in range(s[:-1]):
#       4     print(i)
#       8 # print(s[0])
#       9 # print(s[-1])
#      10 # print(s[1])
#
# TypeError: 'str' object cannot be interpreted as an integer
