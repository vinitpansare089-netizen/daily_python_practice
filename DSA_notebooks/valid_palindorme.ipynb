# %%
s = 'vinit'
    
print(s[0])
print(s[-1])
print(s[1])

word = "python"

print(word[0])
print(word[-1])
print(word[2])
# Out:
# p
# n
# t

# %%
s = 'vinit'

left = 0
right = len(s) - 1

print(right)
# Out:
# 4

# %%
s = 'vinit'

left = 0
right = 4

print(left)
print(right)

print(s[right])
# Out:
# 0
# 4
# t

# %%
s = 'vinit'

left += 1
right += 1

print(left)
# Out:
# 1

# %%
left = 0
right = len(s) - 1

while left < right:
    if s
