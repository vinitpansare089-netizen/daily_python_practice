# %%
prices = [7,1,5,3,6,4]


max_profit = []

def min_max_profit(prices: list[int]):
    min_price = prices[0]

    for price in prices:
        if price < min_price:
            min_price = price

        print(min_price, price)
        
min_max_profit(prices)
# Out:
# 7 7
# 1 1
# 1 5
# 1 3
# 1 6
# 1 4
