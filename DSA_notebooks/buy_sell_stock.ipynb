# %%
prices = [7,1,5,3,6,4]

min_price = prices[0]
max_profit = []

def min_max_profit(prices: list[int]):
    for price in prices:
        if price < min_price:
            min_price = price

        print(min_price, price)
