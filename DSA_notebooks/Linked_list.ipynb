# %%
"""
Linked List programs
"""

class Node:
    def __init__(self):
        self.data = self.data
        self.next = None
# Out:
#   Cell In[1], line 10
#     a =
#         ^
# SyntaxError: invalid syntax
