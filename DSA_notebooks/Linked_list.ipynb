# %%
"""
Linked List programs
"""

class Node:
    def __init__(self):
        self.data = self.data
        self.next = None

        head = a
        a = Node(10)
        b = Node(20)

        a.next = b

        current = head

        while current:
            print(current.head)
            current = current.next
