# %%
"""
Linked List programs
"""

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

       
a = Node(10)
b = Node(20)
c = Node(30)
d = Node(40)

a.next = b
b.next = c
c.next = d
head = a

current = head

while current:
    print(current.data)
    current = current.next
# Out:
# 10
# 20
# 30
# 40

# %%
"""
Searching a data item 
"""


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

target = 30

a = Node(10)
b = Node(20)
c = Node(40)
d = Node(50)

a.next = b
b.next = c
c.next = d

head = a

current = head

while current:
    if current.data == target:
        print("found")
        break

    current = current.next

else:
    print("Not Found")
# Out:
# Not Found

# %%
"""
Insertion of a new Node
"""

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


a = Node(10)
b = Node(20)
c = Node(30)

a.next = b
b.next = c

head = a

d = Node(40)

d.next = head
head = d
current = head


while current:
    print(current.data)
    current = current.next
# Out:
# 40
# 10
# 20
# 30

# %%
def num(x):
    print(x)

a = 10
num(a)
# Out:
# 10

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def insert_head(head):
        current = head

        while current:
            print(current.data)
            current = current.next

    head = Node(10)

    head.next = Node(20)
    head.next.next = Node(30)

    new_node = Node(40)
    new_node.next = head
    head = new_node

    insert_head(head)
# Out:
# 40
# 10
# 20
# 30

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def insert_head(head):
    current = head

    while current:
        print(current.data)
        current = current.next

head = Node(10)
head.next = Node(20)
head.next.next = Node(30)

new_node = Node(40)
while current.next is None:
    current.next = new_node

insert_head(head)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 19
#      16 head.next.next = Node(30)
#      18 new_node = Node(40)
# ---> 19 while current.next is None:
#      20     current.next = new_node
#      22 insert_head(head)
#
# AttributeError: 'NoneType' object has no attribute 'next'
