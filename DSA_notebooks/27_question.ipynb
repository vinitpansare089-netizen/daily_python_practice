# %%
nums = [3,2,2,3]

i = 0

for num in nums:
    if num != 3:
        nums[i] = num
        i += 1

print(nums) 
print(num)
# Out:
# [2, 2, 2, 3]
# 3

# %%
n = int(input())
integer_list = map(int, input().split())
t = tuple(integer_list)


print(hash(t))
# Out:
# -860454829093830431
