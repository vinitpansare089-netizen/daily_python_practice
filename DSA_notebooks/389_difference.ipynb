# %%
s = "abcdef"
t = "abcde"

freq = {}

for char in s:
    freq[char] = freq.get(char, 0) + 1

for char in t:
    if char not in freq:
        print(char)

    # if freq[char] == 0:
    #     print(char)

    # freq[char] -= 1

print("")
