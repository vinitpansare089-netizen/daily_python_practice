# %%
"""
subarray problem
"""
nums = [1, 2, 1]
k = 3

count = {0: 1}
current_sum = 0
result = 0

for num in nums:
    current_sum += num

    needed = current_sum - K

    if needed in count:
        result += count[needed]

    count[current_sum] = count.get(current_sum, 0) + 1

print(result)
