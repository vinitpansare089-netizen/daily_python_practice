# %%
"""
Intersection of two linked list
"""


current1 = headA
current2 = headB

while current1 != current2:

    if current1:
        current1 = current1.next
    else:
        current1 = headB

    if current2:
        current2 = current1.next
    else:
        current2 = headA

    print(current1 or current2)
