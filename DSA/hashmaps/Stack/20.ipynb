# %%
"""
valid parenthesis
"""

def parentheses(s: str) -> bool:

    stack = []

    pairs = {
        '(' : ')',
        '[' : ']',
        '{' : '}'
    }

    for char in s:

        if char in '([{':

            stack.append(char)
# Out:
# None
# 10
# 10
